# %%
import cobra
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def conditions(uptake,name,source):
    o2_uptake=np.linspace(-20,-0.25,20)
    model=cobra.io.read_sbml_model("D:/ScientificReports/iPN730.xml")
    model.solver='glpk'
    model.reactions.EX_cpd00092_e0.bounds=(0,1000)
    model.reactions.EX_cpd19013_e0.bounds=(-1000,1000)
    model.reactions.get_by_id(source).bounds=(uptake,1000)
    df=pd.DataFrame(columns=['Condition','Uptake rate','Oxygen uptake rate','Ethanol','Growth rate','Ethyl acetate','Acetate'])
    for our in o2_uptake:
        model.reactions.EX_cpd00007_e0.bounds=(our,1000)
        #Uptake rate	Oxygen uptake rate	Ethanol	Growth rate	Ethyl acetate
        model.slim_optimize()
        cond=name+"_"+str(abs(round(our,2)))
        etoh=model.reactions.rxn00543_c0.flux
        gr=model.slim_optimize()
        etac=model.reactions.EtAc_t.flux
        ac=model.reactions.rxn00507_c0.flux
        df_temp=pd.DataFrame([[cond,abs(uptake),abs(our),abs(etoh),gr,etac,ac]],columns=['Condition','Uptake rate','Oxygen uptake rate','Ethanol','Growth rate','Ethyl acetate','Acetate'])
        df=df.append(df_temp,ignore_index=True)
    return df

# %%
df_main=pd.DataFrame(columns=['Condition','Uptake rate','Oxygen uptake rate','Ethanol','Growth rate','Ethyl acetate','Acetate'])
carb_sources=['EX_cpd00027_e0','EX_cpd00108_e0','EX_cpd00179_e0','EX_cpd00076_e0']
carb_names=['Glucose','Galactose','Maltose','Sucrose']
uptake_rates=[-2.26,-2.36,-2.2,-1.2]
for name,source,uptake in zip(carb_names,carb_sources,uptake_rates):
    df=conditions(uptake,name,source)
    df_main=df_main.append(df,ignore_index=True)
# Out:
# 'M_abt-L_e' is not a valid SBML 'SId'.
# 'M_abt-L_c' is not a valid SBML 'SId'.
# 'M_lald-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_m' is not a valid SBML 'SId'.
# 'M_trp-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_e' is not a valid SBML 'SId'.
# 'M_asn-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_p' is not a valid SBML 'SId'.
# 'M_arab-D_c' is not a valid SBML 'SId'.
# 'M_arab-D_e' is not a valid SBML 'SId'.
# 'M_tyr-L_m' is not a valid SBML 'SId'.
# 'M_tyr-L_v' is not a valid SBML 'SId'.
# 'M_tyr-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_c' is not a valid SBML 'SId'.
# 'M_glu-L_e' is not a valid SBML 'SId'.
# 'M_glu-L_n' is not a valid SBML 'SId'.
# 'M_glu-L_m' is not a valid SBML 'SId'.
# 'M_glc-D_v' is not a valid SBML 'SId'.
# 'M_glu-L_c' is not a valid SBML 'SId'.
# 'M_glc-D_c' is not a valid SBML 'SId'.
# 'M_glc-D_e' is not a valid SBML 'SId'.
# 'M_glu-L_p' is not a valid SBML 'SId'.
# 'M_manmi1p-D_c' is not a valid SBML 'SId'.
# 'M_glu-L_v' is not a valid SBML 'SId'.
# 'M_phe-L_m' is not a valid SBML 'SId'.
# 'M_phe-L_c' is not a valid SBML 'SId'.
# 'M_phe-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_c' is not a valid SBML 'SId'.
# 'M_lys-L_m' is not a valid SBML 'SId'.
# 'M_lys-L_v' is not a valid SBML 'SId'.
# 'M_met-L_m' is not a valid SBML 'SId'.
# 'M_met-L_c' is not a valid SBML 'SId'.
# 'M_met-L_e' is not a valid SBML 'SId'.
# 'M_dhor-S_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_n' is not a valid SBML 'SId'.
# 'M_asn-L_m' is not a valid SBML 'SId'.
# 'M_thr-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_v' is not a valid SBML 'SId'.
# 'M_thr-L_e' is not a valid SBML 'SId'.
# 'M_cys-L_c' is not a valid SBML 'SId'.
# 'M_cys-L_e' is not a valid SBML 'SId'.
# 'M_acon-T_c' is not a valid SBML 'SId'.
# 'M_pant-R_c' is not a valid SBML 'SId'.
# 'M_man2mi1p-D_c' is not a valid SBML 'SId'.
# 'M_pant-R_m' is not a valid SBML 'SId'.
# 'M_hcys-L_c' is not a valid SBML 'SId'.
# 'M_val-L_c' is not a valid SBML 'SId'.
# 'M_val-L_e' is not a valid SBML 'SId'.
# 'M_val-L_m' is not a valid SBML 'SId'.
# 'M_his-L_c' is not a valid SBML 'SId'.
# 'M_his-L_e' is not a valid SBML 'SId'.
# 'M_his-L_m' is not a valid SBML 'SId'.
# 'M_ru5p-D_c' is not a valid SBML 'SId'.
# 'M_his-L_v' is not a valid SBML 'SId'.
# 'M_sbt-L_c' is not a valid SBML 'SId'.
# 'M_sbt-L_e' is not a valid SBML 'SId'.
# 'M_mev-R_c' is not a valid SBML 'SId'.
# 'M_rib-D_c' is not a valid SBML 'SId'.
# 'M_arg-L_v' is not a valid SBML 'SId'.
# 'M_rib-D_e' is not a valid SBML 'SId'.
# 'M_arg-L_c' is not a valid SBML 'SId'.
# 'M_arg-L_e' is not a valid SBML 'SId'.
# 'M_arg-L_m' is not a valid SBML 'SId'.
# 'M_lac-L_e' is not a valid SBML 'SId'.
# 'M_lac-L_c' is not a valid SBML 'SId'.
# 'M_lac-L_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_c' is not a valid SBML 'SId'.
# 'M_g6p-B_c' is not a valid SBML 'SId'.
# 'M_leu-L_v' is not a valid SBML 'SId'.
# 'M_hom-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_m' is not a valid SBML 'SId'.
# 'M_leu-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_e' is not a valid SBML 'SId'.
# 'M_ertascb-D_c' is not a valid SBML 'SId'.
# 'M_gln-L_c' is not a valid SBML 'SId'.
# 'M_gln-L_e' is not a valid SBML 'SId'.
# 'M_hcys-L_p' is not a valid SBML 'SId'.
# 'M_gln-L_v' is not a valid SBML 'SId'.
# 'M_gln-L_n' is not a valid SBML 'SId'.
# 'M_tag6p-D_c' is not a valid SBML 'SId'.
# 'M_xu5p-D_c' is not a valid SBML 'SId'.
# 'M_mi1p-D_c' is not a valid SBML 'SId'.
# 'M_fglut-S_c' is not a valid SBML 'SId'.
# 'M_asp-L_e' is not a valid SBML 'SId'.
# 'M_asp-L_c' is not a valid SBML 'SId'.
# 'M_sbt-D_e' is not a valid SBML 'SId'.
# 'M_sbt-D_c' is not a valid SBML 'SId'.
# 'M_xyl-D_e' is not a valid SBML 'SId'.
# 'M_xyl-D_c' is not a valid SBML 'SId'.
# 'M_ala-B_c' is not a valid SBML 'SId'.
# 'M_lgt-S_c' is not a valid SBML 'SId'.
# 'M_pser-L_c' is not a valid SBML 'SId'.
# 'M_lgt-S_m' is not a valid SBML 'SId'.
# 'M_pro-L_m' is not a valid SBML 'SId'.
# 'M_pnto-R_e' is not a valid SBML 'SId'.
# 'M_btd-RR_e' is not a valid SBML 'SId'.
# 'M_pro-L_c' is not a valid SBML 'SId'.
# 'M_pro-L_e' is not a valid SBML 'SId'.
# 'M_pnto-R_c' is not a valid SBML 'SId'.
# 'M_btd-RR_c' is not a valid SBML 'SId'.
# 'M_ala-L_e' is not a valid SBML 'SId'.
# 'M_ala-L_c' is not a valid SBML 'SId'.
# 'M_ala-L_m' is not a valid SBML 'SId'.
# 'M_NH4+' is not a valid SBML 'SId'.
# 'M_dad-2_e' is not a valid SBML 'SId'.
# 'M_dad-2_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_c' is not a valid SBML 'SId'.
# 'M_thr-L_m' is not a valid SBML 'SId'.
# 'M_xylu-D_c' is not a valid SBML 'SId'.
# 'M_kynr-L_c' is not a valid SBML 'SId'.
# 'M_thr-LA_c' is not a valid SBML 'SId'.
# 'M_citr-L_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_v' is not a valid SBML 'SId'.
# 'M_saccrp-L_c' is not a valid SBML 'SId'.
# 'M_lac-D_m' is not a valid SBML 'SId'.
# 'M_lac-D_c' is not a valid SBML 'SId'.
# 'M_lac-D_e' is not a valid SBML 'SId'.
# 'M_ser-L_e' is not a valid SBML 'SId'.
# 'M_arab-L_c' is not a valid SBML 'SId'.
# 'M_arab-L_e' is not a valid SBML 'SId'.
# 'M_ser-L_m' is not a valid SBML 'SId'.
# 'M_trans-dd2coa_p' is not a valid SBML 'SId'.
# 'M_ser-L_c' is not a valid SBML 'SId'.
# 'M_ile-L_v' is not a valid SBML 'SId'.
# 'M_ile-L_e' is not a valid SBML 'SId'.
# 'M_ile-L_c' is not a valid SBML 'SId'.
# 'M_mal-L_p' is not a valid SBML 'SId'.
# 'M_ile-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_e' is not a valid SBML 'SId'.
# 'M_mal-L_c' is not a valid SBML 'SId'.
# 'M_asp-L_n' is not a valid SBML 'SId'.
# 'M_asp-L_m' is not a valid SBML 'SId'.
# 'M_asp-L_p' is not a valid SBML 'SId'.
# 'M_asp-L_v' is not a valid SBML 'SId'.
# 'M_dhor-S_n' is not a valid SBML 'SId'.
# 'M_abt-L_e' is not a valid SBML 'SId'.
# 'M_abt-L_c' is not a valid SBML 'SId'.
# 'M_lald-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_m' is not a valid SBML 'SId'.
# 'M_trp-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_e' is not a valid SBML 'SId'.
# 'M_asn-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_p' is not a valid SBML 'SId'.
# 'M_arab-D_c' is not a valid SBML 'SId'.
# 'M_arab-D_e' is not a valid SBML 'SId'.
# 'M_tyr-L_m' is not a valid SBML 'SId'.
# 'M_tyr-L_v' is not a valid SBML 'SId'.
# 'M_tyr-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_c' is not a valid SBML 'SId'.
# 'M_glu-L_e' is not a valid SBML 'SId'.
# 'M_glu-L_n' is not a valid SBML 'SId'.
# 'M_glu-L_m' is not a valid SBML 'SId'.
# 'M_glc-D_v' is not a valid SBML 'SId'.
# 'M_glu-L_c' is not a valid SBML 'SId'.
# 'M_glc-D_c' is not a valid SBML 'SId'.
# 'M_glc-D_e' is not a valid SBML 'SId'.
# 'M_glu-L_p' is not a valid SBML 'SId'.
# 'M_manmi1p-D_c' is not a valid SBML 'SId'.
# 'M_glu-L_v' is not a valid SBML 'SId'.
# 'M_phe-L_m' is not a valid SBML 'SId'.
# 'M_phe-L_c' is not a valid SBML 'SId'.
# 'M_phe-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_c' is not a valid SBML 'SId'.
# 'M_lys-L_m' is not a valid SBML 'SId'.
# 'M_lys-L_v' is not a valid SBML 'SId'.
# 'M_met-L_m' is not a valid SBML 'SId'.
# 'M_met-L_c' is not a valid SBML 'SId'.
# 'M_met-L_e' is not a valid SBML 'SId'.
# 'M_dhor-S_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_n' is not a valid SBML 'SId'.
# 'M_asn-L_m' is not a valid SBML 'SId'.
# 'M_thr-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_v' is not a valid SBML 'SId'.
# 'M_thr-L_e' is not a valid SBML 'SId'.
# 'M_cys-L_c' is not a valid SBML 'SId'.
# 'M_cys-L_e' is not a valid SBML 'SId'.
# 'M_acon-T_c' is not a valid SBML 'SId'.
# 'M_pant-R_c' is not a valid SBML 'SId'.
# 'M_man2mi1p-D_c' is not a valid SBML 'SId'.
# 'M_pant-R_m' is not a valid SBML 'SId'.
# 'M_hcys-L_c' is not a valid SBML 'SId'.
# 'M_val-L_c' is not a valid SBML 'SId'.
# 'M_val-L_e' is not a valid SBML 'SId'.
# 'M_val-L_m' is not a valid SBML 'SId'.
# 'M_his-L_c' is not a valid SBML 'SId'.
# 'M_his-L_e' is not a valid SBML 'SId'.
# 'M_his-L_m' is not a valid SBML 'SId'.
# 'M_ru5p-D_c' is not a valid SBML 'SId'.
# 'M_his-L_v' is not a valid SBML 'SId'.
# 'M_sbt-L_c' is not a valid SBML 'SId'.
# 'M_sbt-L_e' is not a valid SBML 'SId'.
# 'M_mev-R_c' is not a valid SBML 'SId'.
# 'M_rib-D_c' is not a valid SBML 'SId'.
# 'M_arg-L_v' is not a valid SBML 'SId'.
# 'M_rib-D_e' is not a valid SBML 'SId'.
# 'M_arg-L_c' is not a valid SBML 'SId'.
# 'M_arg-L_e' is not a valid SBML 'SId'.
# 'M_arg-L_m' is not a valid SBML 'SId'.
# 'M_lac-L_e' is not a valid SBML 'SId'.
# 'M_lac-L_c' is not a valid SBML 'SId'.
# 'M_lac-L_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_c' is not a valid SBML 'SId'.
# 'M_g6p-B_c' is not a valid SBML 'SId'.
# 'M_leu-L_v' is not a valid SBML 'SId'.
# 'M_hom-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_m' is not a valid SBML 'SId'.
# 'M_leu-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_e' is not a valid SBML 'SId'.
# 'M_ertascb-D_c' is not a valid SBML 'SId'.
# 'M_gln-L_c' is not a valid SBML 'SId'.
# 'M_gln-L_e' is not a valid SBML 'SId'.
# 'M_hcys-L_p' is not a valid SBML 'SId'.
# 'M_gln-L_v' is not a valid SBML 'SId'.
# 'M_gln-L_n' is not a valid SBML 'SId'.
# 'M_tag6p-D_c' is not a valid SBML 'SId'.
# 'M_xu5p-D_c' is not a valid SBML 'SId'.
# 'M_mi1p-D_c' is not a valid SBML 'SId'.
# 'M_fglut-S_c' is not a valid SBML 'SId'.
# 'M_asp-L_e' is not a valid SBML 'SId'.
# 'M_asp-L_c' is not a valid SBML 'SId'.
# 'M_sbt-D_e' is not a valid SBML 'SId'.
# 'M_sbt-D_c' is not a valid SBML 'SId'.
# 'M_xyl-D_e' is not a valid SBML 'SId'.
# 'M_xyl-D_c' is not a valid SBML 'SId'.
# 'M_ala-B_c' is not a valid SBML 'SId'.
# 'M_lgt-S_c' is not a valid SBML 'SId'.
# 'M_pser-L_c' is not a valid SBML 'SId'.
# 'M_lgt-S_m' is not a valid SBML 'SId'.
# 'M_pro-L_m' is not a valid SBML 'SId'.
# 'M_pnto-R_e' is not a valid SBML 'SId'.
# 'M_btd-RR_e' is not a valid SBML 'SId'.
# 'M_pro-L_c' is not a valid SBML 'SId'.
# 'M_pro-L_e' is not a valid SBML 'SId'.
# 'M_pnto-R_c' is not a valid SBML 'SId'.
# 'M_btd-RR_c' is not a valid SBML 'SId'.
# 'M_ala-L_e' is not a valid SBML 'SId'.
# 'M_ala-L_c' is not a valid SBML 'SId'.
# 'M_ala-L_m' is not a valid SBML 'SId'.
# 'M_NH4+' is not a valid SBML 'SId'.
# 'M_dad-2_e' is not a valid SBML 'SId'.
# 'M_dad-2_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_c' is not a valid SBML 'SId'.
# 'M_thr-L_m' is not a valid SBML 'SId'.
# 'M_xylu-D_c' is not a valid SBML 'SId'.
# 'M_kynr-L_c' is not a valid SBML 'SId'.
# 'M_thr-LA_c' is not a valid SBML 'SId'.
# 'M_citr-L_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_v' is not a valid SBML 'SId'.
# 'M_saccrp-L_c' is not a valid SBML 'SId'.
# 'M_lac-D_m' is not a valid SBML 'SId'.
# 'M_lac-D_c' is not a valid SBML 'SId'.
# 'M_lac-D_e' is not a valid SBML 'SId'.
# 'M_ser-L_e' is not a valid SBML 'SId'.
# 'M_arab-L_c' is not a valid SBML 'SId'.
# 'M_arab-L_e' is not a valid SBML 'SId'.
# 'M_ser-L_m' is not a valid SBML 'SId'.
# 'M_trans-dd2coa_p' is not a valid SBML 'SId'.
# 'M_ser-L_c' is not a valid SBML 'SId'.
# 'M_ile-L_v' is not a valid SBML 'SId'.
# 'M_ile-L_e' is not a valid SBML 'SId'.
# 'M_ile-L_c' is not a valid SBML 'SId'.
# 'M_mal-L_p' is not a valid SBML 'SId'.
# 'M_ile-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_e' is not a valid SBML 'SId'.
# 'M_mal-L_c' is not a valid SBML 'SId'.
# 'M_asp-L_n' is not a valid SBML 'SId'.
# 'M_asp-L_m' is not a valid SBML 'SId'.
# 'M_asp-L_p' is not a valid SBML 'SId'.
# 'M_asp-L_v' is not a valid SBML 'SId'.
# 'M_dhor-S_n' is not a valid SBML 'SId'.
# 'M_abt-L_e' is not a valid SBML 'SId'.
# 'M_abt-L_c' is not a valid SBML 'SId'.
# 'M_lald-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_m' is not a valid SBML 'SId'.
# 'M_trp-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_e' is not a valid SBML 'SId'.
# 'M_asn-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_p' is not a valid SBML 'SId'.
# 'M_arab-D_c' is not a valid SBML 'SId'.
# 'M_arab-D_e' is not a valid SBML 'SId'.
# 'M_tyr-L_m' is not a valid SBML 'SId'.
# 'M_tyr-L_v' is not a valid SBML 'SId'.
# 'M_tyr-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_c' is not a valid SBML 'SId'.
# 'M_glu-L_e' is not a valid SBML 'SId'.
# 'M_glu-L_n' is not a valid SBML 'SId'.
# 'M_glu-L_m' is not a valid SBML 'SId'.
# 'M_glc-D_v' is not a valid SBML 'SId'.
# 'M_glu-L_c' is not a valid SBML 'SId'.
# 'M_glc-D_c' is not a valid SBML 'SId'.
# 'M_glc-D_e' is not a valid SBML 'SId'.
# 'M_glu-L_p' is not a valid SBML 'SId'.
# 'M_manmi1p-D_c' is not a valid SBML 'SId'.
# 'M_glu-L_v' is not a valid SBML 'SId'.
# 'M_phe-L_m' is not a valid SBML 'SId'.
# 'M_phe-L_c' is not a valid SBML 'SId'.
# 'M_phe-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_c' is not a valid SBML 'SId'.
# 'M_lys-L_m' is not a valid SBML 'SId'.
# 'M_lys-L_v' is not a valid SBML 'SId'.
# 'M_met-L_m' is not a valid SBML 'SId'.
# 'M_met-L_c' is not a valid SBML 'SId'.
# 'M_met-L_e' is not a valid SBML 'SId'.
# 'M_dhor-S_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_n' is not a valid SBML 'SId'.
# 'M_asn-L_m' is not a valid SBML 'SId'.
# 'M_thr-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_v' is not a valid SBML 'SId'.
# 'M_thr-L_e' is not a valid SBML 'SId'.
# 'M_cys-L_c' is not a valid SBML 'SId'.
# 'M_cys-L_e' is not a valid SBML 'SId'.
# 'M_acon-T_c' is not a valid SBML 'SId'.
# 'M_pant-R_c' is not a valid SBML 'SId'.
# 'M_man2mi1p-D_c' is not a valid SBML 'SId'.
# 'M_pant-R_m' is not a valid SBML 'SId'.
# 'M_hcys-L_c' is not a valid SBML 'SId'.
# 'M_val-L_c' is not a valid SBML 'SId'.
# 'M_val-L_e' is not a valid SBML 'SId'.
# 'M_val-L_m' is not a valid SBML 'SId'.
# 'M_his-L_c' is not a valid SBML 'SId'.
# 'M_his-L_e' is not a valid SBML 'SId'.
# 'M_his-L_m' is not a valid SBML 'SId'.
# 'M_ru5p-D_c' is not a valid SBML 'SId'.
# 'M_his-L_v' is not a valid SBML 'SId'.
# 'M_sbt-L_c' is not a valid SBML 'SId'.
# 'M_sbt-L_e' is not a valid SBML 'SId'.
# 'M_mev-R_c' is not a valid SBML 'SId'.
# 'M_rib-D_c' is not a valid SBML 'SId'.
# 'M_arg-L_v' is not a valid SBML 'SId'.
# 'M_rib-D_e' is not a valid SBML 'SId'.
# 'M_arg-L_c' is not a valid SBML 'SId'.
# 'M_arg-L_e' is not a valid SBML 'SId'.
# 'M_arg-L_m' is not a valid SBML 'SId'.
# 'M_lac-L_e' is not a valid SBML 'SId'.
# 'M_lac-L_c' is not a valid SBML 'SId'.
# 'M_lac-L_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_c' is not a valid SBML 'SId'.
# 'M_g6p-B_c' is not a valid SBML 'SId'.
# 'M_leu-L_v' is not a valid SBML 'SId'.
# 'M_hom-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_m' is not a valid SBML 'SId'.
# 'M_leu-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_e' is not a valid SBML 'SId'.
# 'M_ertascb-D_c' is not a valid SBML 'SId'.
# 'M_gln-L_c' is not a valid SBML 'SId'.
# 'M_gln-L_e' is not a valid SBML 'SId'.
# 'M_hcys-L_p' is not a valid SBML 'SId'.
# 'M_gln-L_v' is not a valid SBML 'SId'.
# 'M_gln-L_n' is not a valid SBML 'SId'.
# 'M_tag6p-D_c' is not a valid SBML 'SId'.
# 'M_xu5p-D_c' is not a valid SBML 'SId'.
# 'M_mi1p-D_c' is not a valid SBML 'SId'.
# 'M_fglut-S_c' is not a valid SBML 'SId'.
# 'M_asp-L_e' is not a valid SBML 'SId'.
# 'M_asp-L_c' is not a valid SBML 'SId'.
# 'M_sbt-D_e' is not a valid SBML 'SId'.
# 'M_sbt-D_c' is not a valid SBML 'SId'.
# 'M_xyl-D_e' is not a valid SBML 'SId'.
# 'M_xyl-D_c' is not a valid SBML 'SId'.
# 'M_ala-B_c' is not a valid SBML 'SId'.
# 'M_lgt-S_c' is not a valid SBML 'SId'.
# 'M_pser-L_c' is not a valid SBML 'SId'.
# 'M_lgt-S_m' is not a valid SBML 'SId'.
# 'M_pro-L_m' is not a valid SBML 'SId'.
# 'M_pnto-R_e' is not a valid SBML 'SId'.
# 'M_btd-RR_e' is not a valid SBML 'SId'.
# 'M_pro-L_c' is not a valid SBML 'SId'.
# 'M_pro-L_e' is not a valid SBML 'SId'.
# 'M_pnto-R_c' is not a valid SBML 'SId'.
# 'M_btd-RR_c' is not a valid SBML 'SId'.
# 'M_ala-L_e' is not a valid SBML 'SId'.
# 'M_ala-L_c' is not a valid SBML 'SId'.
# 'M_ala-L_m' is not a valid SBML 'SId'.
# 'M_NH4+' is not a valid SBML 'SId'.
# 'M_dad-2_e' is not a valid SBML 'SId'.
# 'M_dad-2_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_c' is not a valid SBML 'SId'.
# 'M_thr-L_m' is not a valid SBML 'SId'.
# 'M_xylu-D_c' is not a valid SBML 'SId'.
# 'M_kynr-L_c' is not a valid SBML 'SId'.
# 'M_thr-LA_c' is not a valid SBML 'SId'.
# 'M_citr-L_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_v' is not a valid SBML 'SId'.
# 'M_saccrp-L_c' is not a valid SBML 'SId'.
# 'M_lac-D_m' is not a valid SBML 'SId'.
# 'M_lac-D_c' is not a valid SBML 'SId'.
# 'M_lac-D_e' is not a valid SBML 'SId'.
# 'M_ser-L_e' is not a valid SBML 'SId'.
# 'M_arab-L_c' is not a valid SBML 'SId'.
# 'M_arab-L_e' is not a valid SBML 'SId'.
# 'M_ser-L_m' is not a valid SBML 'SId'.
# 'M_trans-dd2coa_p' is not a valid SBML 'SId'.
# 'M_ser-L_c' is not a valid SBML 'SId'.
# 'M_ile-L_v' is not a valid SBML 'SId'.
# 'M_ile-L_e' is not a valid SBML 'SId'.
# 'M_ile-L_c' is not a valid SBML 'SId'.
# 'M_mal-L_p' is not a valid SBML 'SId'.
# 'M_ile-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_e' is not a valid SBML 'SId'.
# 'M_mal-L_c' is not a valid SBML 'SId'.
# 'M_asp-L_n' is not a valid SBML 'SId'.
# 'M_asp-L_m' is not a valid SBML 'SId'.
# 'M_asp-L_p' is not a valid SBML 'SId'.
# 'M_asp-L_v' is not a valid SBML 'SId'.
# 'M_dhor-S_n' is not a valid SBML 'SId'.
# 'M_abt-L_e' is not a valid SBML 'SId'.
# 'M_abt-L_c' is not a valid SBML 'SId'.
# 'M_lald-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_m' is not a valid SBML 'SId'.
# 'M_trp-L_c' is not a valid SBML 'SId'.
# 'M_trp-L_e' is not a valid SBML 'SId'.
# 'M_asn-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_p' is not a valid SBML 'SId'.
# 'M_arab-D_c' is not a valid SBML 'SId'.
# 'M_arab-D_e' is not a valid SBML 'SId'.
# 'M_tyr-L_m' is not a valid SBML 'SId'.
# 'M_tyr-L_v' is not a valid SBML 'SId'.
# 'M_tyr-L_e' is not a valid SBML 'SId'.
# 'M_tyr-L_c' is not a valid SBML 'SId'.
# 'M_glu-L_e' is not a valid SBML 'SId'.
# 'M_glu-L_n' is not a valid SBML 'SId'.
# 'M_glu-L_m' is not a valid SBML 'SId'.
# 'M_glc-D_v' is not a valid SBML 'SId'.
# 'M_glu-L_c' is not a valid SBML 'SId'.
# 'M_glc-D_c' is not a valid SBML 'SId'.
# 'M_glc-D_e' is not a valid SBML 'SId'.
# 'M_glu-L_p' is not a valid SBML 'SId'.
# 'M_manmi1p-D_c' is not a valid SBML 'SId'.
# 'M_glu-L_v' is not a valid SBML 'SId'.
# 'M_phe-L_m' is not a valid SBML 'SId'.
# 'M_phe-L_c' is not a valid SBML 'SId'.
# 'M_phe-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_e' is not a valid SBML 'SId'.
# 'M_lys-L_c' is not a valid SBML 'SId'.
# 'M_lys-L_m' is not a valid SBML 'SId'.
# 'M_lys-L_v' is not a valid SBML 'SId'.
# 'M_met-L_m' is not a valid SBML 'SId'.
# 'M_met-L_c' is not a valid SBML 'SId'.
# 'M_met-L_e' is not a valid SBML 'SId'.
# 'M_dhor-S_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_c' is not a valid SBML 'SId'.
# 'M_mi145tp-D_n' is not a valid SBML 'SId'.
# 'M_asn-L_m' is not a valid SBML 'SId'.
# 'M_thr-L_c' is not a valid SBML 'SId'.
# 'M_asn-L_v' is not a valid SBML 'SId'.
# 'M_thr-L_e' is not a valid SBML 'SId'.
# 'M_cys-L_c' is not a valid SBML 'SId'.
# 'M_cys-L_e' is not a valid SBML 'SId'.
# 'M_acon-T_c' is not a valid SBML 'SId'.
# 'M_pant-R_c' is not a valid SBML 'SId'.
# 'M_man2mi1p-D_c' is not a valid SBML 'SId'.
# 'M_pant-R_m' is not a valid SBML 'SId'.
# 'M_hcys-L_c' is not a valid SBML 'SId'.
# 'M_val-L_c' is not a valid SBML 'SId'.
# 'M_val-L_e' is not a valid SBML 'SId'.
# 'M_val-L_m' is not a valid SBML 'SId'.
# 'M_his-L_c' is not a valid SBML 'SId'.
# 'M_his-L_e' is not a valid SBML 'SId'.
# 'M_his-L_m' is not a valid SBML 'SId'.
# 'M_ru5p-D_c' is not a valid SBML 'SId'.
# 'M_his-L_v' is not a valid SBML 'SId'.
# 'M_sbt-L_c' is not a valid SBML 'SId'.
# 'M_sbt-L_e' is not a valid SBML 'SId'.
# 'M_mev-R_c' is not a valid SBML 'SId'.
# 'M_rib-D_c' is not a valid SBML 'SId'.
# 'M_arg-L_v' is not a valid SBML 'SId'.
# 'M_rib-D_e' is not a valid SBML 'SId'.
# 'M_arg-L_c' is not a valid SBML 'SId'.
# 'M_arg-L_e' is not a valid SBML 'SId'.
# 'M_arg-L_m' is not a valid SBML 'SId'.
# 'M_lac-L_e' is not a valid SBML 'SId'.
# 'M_lac-L_c' is not a valid SBML 'SId'.
# 'M_lac-L_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_m' is not a valid SBML 'SId'.
# 'M_4hpro-LT_c' is not a valid SBML 'SId'.
# 'M_g6p-B_c' is not a valid SBML 'SId'.
# 'M_leu-L_v' is not a valid SBML 'SId'.
# 'M_hom-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_m' is not a valid SBML 'SId'.
# 'M_leu-L_c' is not a valid SBML 'SId'.
# 'M_leu-L_e' is not a valid SBML 'SId'.
# 'M_ertascb-D_c' is not a valid SBML 'SId'.
# 'M_gln-L_c' is not a valid SBML 'SId'.
# 'M_gln-L_e' is not a valid SBML 'SId'.
# 'M_hcys-L_p' is not a valid SBML 'SId'.
# 'M_gln-L_v' is not a valid SBML 'SId'.
# 'M_gln-L_n' is not a valid SBML 'SId'.
# 'M_tag6p-D_c' is not a valid SBML 'SId'.
# 'M_xu5p-D_c' is not a valid SBML 'SId'.
# 'M_mi1p-D_c' is not a valid SBML 'SId'.
# 'M_fglut-S_c' is not a valid SBML 'SId'.
# 'M_asp-L_e' is not a valid SBML 'SId'.
# 'M_asp-L_c' is not a valid SBML 'SId'.
# 'M_sbt-D_e' is not a valid SBML 'SId'.
# 'M_sbt-D_c' is not a valid SBML 'SId'.
# 'M_xyl-D_e' is not a valid SBML 'SId'.
# 'M_xyl-D_c' is not a valid SBML 'SId'.
# 'M_ala-B_c' is not a valid SBML 'SId'.
# 'M_lgt-S_c' is not a valid SBML 'SId'.
# 'M_pser-L_c' is not a valid SBML 'SId'.
# 'M_lgt-S_m' is not a valid SBML 'SId'.
# 'M_pro-L_m' is not a valid SBML 'SId'.
# 'M_pnto-R_e' is not a valid SBML 'SId'.
# 'M_btd-RR_e' is not a valid SBML 'SId'.
# 'M_pro-L_c' is not a valid SBML 'SId'.
# 'M_pro-L_e' is not a valid SBML 'SId'.
# 'M_pnto-R_c' is not a valid SBML 'SId'.
# 'M_btd-RR_c' is not a valid SBML 'SId'.
# 'M_ala-L_e' is not a valid SBML 'SId'.
# 'M_ala-L_c' is not a valid SBML 'SId'.
# 'M_ala-L_m' is not a valid SBML 'SId'.
# 'M_NH4+' is not a valid SBML 'SId'.
# 'M_dad-2_e' is not a valid SBML 'SId'.
# 'M_dad-2_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_c' is not a valid SBML 'SId'.
# 'M_thr-L_m' is not a valid SBML 'SId'.
# 'M_xylu-D_c' is not a valid SBML 'SId'.
# 'M_kynr-L_c' is not a valid SBML 'SId'.
# 'M_thr-LA_c' is not a valid SBML 'SId'.
# 'M_citr-L_c' is not a valid SBML 'SId'.
# 'M_L-Cystine_v' is not a valid SBML 'SId'.
# 'M_saccrp-L_c' is not a valid SBML 'SId'.
# 'M_lac-D_m' is not a valid SBML 'SId'.
# 'M_lac-D_c' is not a valid SBML 'SId'.
# 'M_lac-D_e' is not a valid SBML 'SId'.
# 'M_ser-L_e' is not a valid SBML 'SId'.
# 'M_arab-L_c' is not a valid SBML 'SId'.
# 'M_arab-L_e' is not a valid SBML 'SId'.
# 'M_ser-L_m' is not a valid SBML 'SId'.
# 'M_trans-dd2coa_p' is not a valid SBML 'SId'.
# 'M_ser-L_c' is not a valid SBML 'SId'.
# 'M_ile-L_v' is not a valid SBML 'SId'.
# 'M_ile-L_e' is not a valid SBML 'SId'.
# 'M_ile-L_c' is not a valid SBML 'SId'.
# 'M_mal-L_p' is not a valid SBML 'SId'.
# 'M_ile-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_m' is not a valid SBML 'SId'.
# 'M_mal-L_e' is not a valid SBML 'SId'.
# 'M_mal-L_c' is not a valid SBML 'SId'.
# 'M_asp-L_n' is not a valid SBML 'SId'.
# 'M_asp-L_m' is not a valid SBML 'SId'.
# 'M_asp-L_p' is not a valid SBML 'SId'.
# 'M_asp-L_v' is not a valid SBML 'SId'.
# 'M_dhor-S_n' is not a valid SBML 'SId'.

# %%
df_main["Carbon Source"]=df_main['Condition'].apply(lambda x:x[0:x.index('_')])
df_main
# Out:
#           Condition  Uptake rate  Oxygen uptake rate       Ethanol  \
# 0      Glucose_20.0         2.26           20.000000  0.000000e+00
# 1     Glucose_18.96         2.26           18.960526  0.000000e+00
# 2     Glucose_17.92         2.26           17.921053  0.000000e+00
# 3     Glucose_16.88         2.26           16.881579  0.000000e+00
# 4     Glucose_15.84         2.26           15.842105  0.000000e+00
# 5      Glucose_14.8         2.26           14.802632  0.000000e+00
# 6     Glucose_13.76         2.26           13.763158  0.000000e+00
# 7     Glucose_12.72         2.26           12.723684  0.000000e+00
# 8     Glucose_11.68         2.26           11.684211  0.000000e+00
# 9     Glucose_10.64         2.26           10.644737  0.000000e+00
# 10     Glucose_9.61         2.26            9.605263  0.000000e+00
# 11     Glucose_8.57         2.26            8.565789  0.000000e+00
# 12     Glucose_7.53         2.26            7.526316  0.000000e+00
# 13     Glucose_6.49         2.26            6.486842  0.000000e+00
# 14     Glucose_5.45         2.26            5.447368  4.093686e-02
# 15     Glucose_4.41         2.26            4.407895  4.754253e-01
# 16     Glucose_3.37         2.26            3.368421  9.099137e-01
# 17     Glucose_2.33         2.26            2.328947  1.728075e+00
# 18     Glucose_1.29         2.26            1.289474  2.581020e+00
# 19     Glucose_0.25         2.26            0.250000  3.699910e+00
# 20   Galactose_20.0         2.36           20.000000  0.000000e+00
# 21  Galactose_18.96         2.36           18.960526  0.000000e+00
# 22  Galactose_17.92         2.36           17.921053  0.000000e+00
# 23  Galactose_16.88         2.36           16.881579  0.000000e+00
# 24  Galactose_15.84         2.36           15.842105  0.000000e+00
# 25   Galactose_14.8         2.36           14.802632  0.000000e+00
# 26  Galactose_13.76         2.36           13.763158  0.000000e+00
# 27  Galactose_12.72         2.36           12.723684  0.000000e+00
# 28  Galactose_11.68         2.36           11.684211  0.000000e+00
# 29  Galactose_10.64         2.36           10.644737  0.000000e+00
# ..              ...          ...                 ...           ...
# 50     Maltose_9.61         2.20            9.605263  1.523395e+00
# 51     Maltose_8.57         2.20            8.565789  1.957884e+00
# 52     Maltose_7.53         2.20            7.526316  2.519450e+00
# 53     Maltose_6.49         2.20            6.486842  3.372395e+00
# 54     Maltose_5.45         2.20            5.447368  4.225340e+00
# 55     Maltose_4.41         2.20            4.407895  5.078285e+00
# 56     Maltose_3.37         2.20            3.368421  5.931230e+00
# 57     Maltose_2.33         2.20            2.328947  6.784175e+00
# 58     Maltose_1.29         2.20            1.289474  7.701344e+00
# 59     Maltose_0.25         2.20            0.250000  9.138541e+00
# 60     Sucrose_20.0         1.20           20.000000  1.364649e-15
# 61    Sucrose_18.96         1.20           18.960526  1.364649e-15
# 62    Sucrose_17.92         1.20           17.921053  1.364649e-15
# 63    Sucrose_16.88         1.20           16.881579  1.364649e-15
# 64    Sucrose_15.84         1.20           15.842105  1.364649e-15
# 65     Sucrose_14.8         1.20           14.802632  1.364649e-15
# 66    Sucrose_13.76         1.20           13.763158  1.364649e-15
# 67    Sucrose_12.72         1.20           12.723684  1.364649e-15
# 68    Sucrose_11.68         1.20           11.684211  1.364649e-15
# 69    Sucrose_10.64         1.20           10.644737  1.364649e-15
# 70     Sucrose_9.61         1.20            9.605263  1.364649e-15
# 71     Sucrose_8.57         1.20            8.565789  1.364649e-15
# 72     Sucrose_7.53         1.20            7.526316  3.411542e-01
# 73     Sucrose_6.49         1.20            6.486842  7.756426e-01
# 74     Sucrose_5.45         1.20            5.447368  1.210131e+00
# 75     Sucrose_4.41         1.20            4.407895  1.857839e+00
# 76     Sucrose_3.37         1.20            3.368421  2.710784e+00
# 77     Sucrose_2.33         1.20            2.328947  3.563729e+00
# 78     Sucrose_1.29         1.20            1.289474  4.416674e+00
# 79     Sucrose_0.25         1.20            0.250000  5.674445e+00
#
#     Growth rate  Ethyl acetate   Acetate Carbon Source
# 0      0.220291       0.000000  0.173941       Glucose
# 1      0.220291       0.000000  0.173941       Glucose
# 2      0.220291       0.000000  0.173941       Glucose
# 3      0.220291       0.000000  0.173941       Glucose
# 4      0.220291       0.000000  0.173941       Glucose
# 5      0.220291       0.000000  0.173941       Glucose
# 6      0.220291       0.000000  0.173941       Glucose
# 7      0.220291       0.000000  0.173941       Glucose
# 8      0.220291       0.000000  0.173941       Glucose
# 9      0.220291       0.000000  0.173941       Glucose
# 10     0.220291       0.000000  0.173941       Glucose
# 11     0.220291       0.000000  0.173941       Glucose
# 12     0.220291       0.000000  0.173941       Glucose
# 13     0.220291       0.000000  0.173941       Glucose
# 14     0.217357       0.040937  0.212562       Glucose
# 15     0.186216       0.475425  0.622461       Glucose
# 16     0.155075       0.909914  1.032361       Glucose
# 17     0.123935       0.768893  0.866752       Glucose
# 18     0.092794       0.575696  0.648967       Glucose
# 19     0.060751       0.000000  0.047969       Glucose
# 20     0.327512       0.000000  0.258603     Galactose
# 21     0.327512       0.000000  0.258603     Galactose
# 22     0.327512       0.000000  0.258603     Galactose
# 23     0.327512       0.000000  0.258603     Galactose
# 24     0.327512       0.000000  0.258603     Galactose
# 25     0.327512       0.000000  0.258603     Galactose
# 26     0.327512       0.000000  0.258603     Galactose
# 27     0.327512       0.000000  0.258603     Galactose
# 28     0.327512       0.000000  0.258603     Galactose
# 29     0.327512       0.000000  0.258603     Galactose
# ..          ...            ...       ...           ...
# 50     0.417174       1.523395  1.852795       Maltose
# 51     0.386033       1.957884  2.262695       Maltose
# 52     0.354892       2.201756  2.481979       Maltose
# 53     0.323752       2.008559  2.264193       Maltose
# 54     0.292611       1.815363  2.046408       Maltose
# 55     0.261471       1.622166  1.828623       Maltose
# 56     0.230330       1.428969  1.610838       Maltose
# 57     0.199189       1.235773  1.393053       Maltose
# 58     0.168010       0.946948  1.079608       Maltose
# 59     0.130128       0.000000  0.102749       Maltose
# 60     0.331411       0.000000  0.261682       Sucrose
# 61     0.331411       0.000000  0.261682       Sucrose
# 62     0.331411       0.000000  0.261682       Sucrose
# 63     0.331411       0.000000  0.261682       Sucrose
# 64     0.331411       0.000000  0.261682       Sucrose
# 65     0.331411       0.000000  0.261682       Sucrose
# 66     0.331411       0.000000  0.261682       Sucrose
# 67     0.331411       0.000000  0.261682       Sucrose
# 68     0.331411       0.000000  0.261682       Sucrose
# 69     0.331411       0.000000  0.261682       Sucrose
# 70     0.331411       0.000000  0.261682       Sucrose
# 71     0.331411       0.000000  0.261682       Sucrose
# 72     0.306959       0.341154  0.583529       Sucrose
# 73     0.275819       0.775643  0.993429       Sucrose
# 74     0.244678       1.210131  1.403329       Sucrose
# 75     0.213538       1.324790  1.493399       Sucrose
# 76     0.182397       1.131594  1.275614       Sucrose
# 77     0.151257       0.938397  1.057829       Sucrose
# 78     0.120116       0.745201  0.840044       Sucrose
# 79     0.085939       0.000000  0.067857       Sucrose
#
# [80 rows x 8 columns]

# %%
df_main.to_csv("D:/ScientificReports/CarbEthEtAC.csv")

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(7,7))

# %%
df_glucose=df_main[df_main['Carbon Source']=='Glucose'][12:19]
ax1.plot(df_glucose['Oxygen uptake rate'],df_glucose['Ethyl acetate'],'ro-')
ax1.plot(df_glucose['Oxygen uptake rate'],df_glucose['Ethanol'],'bo-')
ax1.plot(df_glucose['Oxygen uptake rate'],df_glucose['Acetate'],'go-')
ax1.plot(df_glucose['Oxygen uptake rate'],df_glucose['Growth rate'],'ko-')
ax1.set_title('Glucose')
# Out:
# Text(0.5, 1, 'Glucose')

# %%
df_galactose=df_main[df_main['Carbon Source']=='Galactose'][12:19]
ax2.plot(df_galactose['Oxygen uptake rate'],df_galactose['Ethyl acetate'],'ro-')
ax2.plot(df_galactose['Oxygen uptake rate'],df_galactose['Ethanol'],'bo-')
ax2.plot(df_galactose['Oxygen uptake rate'],df_galactose['Acetate'],'go-')
ax2.plot(df_galactose['Oxygen uptake rate'],df_galactose['Growth rate'],'ko-')
ax2.set_title('Galactose')
ax2.legend(['Ethyl Acetate','Ethanol','Acetate','Growth rate'])

# %%
df_maltose=df_main[df_main['Carbon Source']=='Maltose'][7:19]
ax3.plot(df_maltose['Oxygen uptake rate'],df_maltose['Ethyl acetate'],'ro-')
ax3.plot(df_maltose['Oxygen uptake rate'],df_maltose['Ethanol'],'bo-')
ax3.plot(df_maltose['Oxygen uptake rate'],df_maltose['Acetate'],'go-')
ax3.plot(df_maltose['Oxygen uptake rate'],df_maltose['Growth rate'],'ko-')
ax3.set_title('Maltose')
# Out:
# Text(0.5, 1, 'Maltose')

# %%
df_sucrose=df_main[df_main['Carbon Source']=='Sucrose'][12:19]
ax4.plot(df_sucrose['Oxygen uptake rate'],df_sucrose['Ethyl acetate'],'ro-')
ax4.plot(df_sucrose['Oxygen uptake rate'],df_sucrose['Ethanol'],'bo-')
ax4.plot(df_sucrose['Oxygen uptake rate'],df_sucrose['Acetate'],'go-')
ax4.plot(df_sucrose['Oxygen uptake rate'],df_sucrose['Growth rate'],'ko-')
ax4.set_title('Sucrose')
# Out:
# Text(0.5, 1, 'Sucrose')

# %%
fig.savefig('D:/ScientificReports/CarbEtac.png',dpi=600)

# %%
fig
